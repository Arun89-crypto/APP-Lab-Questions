# %%
from tkinter import *
import tkinter as tk
root=tk.Tk()

root.title('STUDENT REGISTRATION FORM')
root.geometry("600x1000")
root.configure(background='purple1')

Fname=tk.StringVar()
Lname=tk.StringVar()
Date=tk.IntVar()
Mail=tk.StringVar()
Mobile=tk.IntVar()
gender1 = tk.IntVar()
gender2=tk.IntVar()
Address=tk.StringVar()
city=tk.StringVar()
pin=tk.IntVar()
state=tk.StringVar()
Country=tk.StringVar()
hob1=tk.IntVar()
hob2=tk.IntVar()
hob3=tk.IntVar()
hob4=tk.IntVar()
hob5=tk.StringVar()
tenb=tk.StringVar()
tenp=tk.StringVar()
teny=tk.IntVar()
interb=tk.StringVar()
interp=tk.StringVar()
intery=tk.IntVar()
course1 = tk.IntVar()
course2=tk.IntVar()
course3=tk.IntVar()
course4=tk.IntVar()

Fname_label = tk.Label(root, text = 'First name',width=10).grid(row=0,column=0,padx=5,pady=5) 
Fname_entry = tk.Entry(root,textvariable = Fname).grid(row=0,column=1)

Lname_label = tk.Label(root, text = 'Last name',width=10).grid(row=1,column=0,padx=5,pady=5) 
Lname_entry = tk.Entry(root,textvariable = Lname).grid(row=1,column=1)

Date_label = tk.Label(root,text='Date',width=10).grid(row=2,column=0)
Date_entry=tk.Entry(root,textvariable=Date, width=10).grid(row=2,column=1)

Email_label=tk.Label(root,text='Email',width=10).grid(row=3,column=0)
Email_entry=tk.Entry(root,textvariable=Mail).grid(row=3,column=1,pady=5)

gender_lable=tk.Label(root,text="Gender",width=10).grid(row=4,column=0) 
radiobutton_1 = tk.Radiobutton(root, text='Male',variable=gender1).grid(row=4,column=1,pady=5) 
radiobutton_2 = tk.Radiobutton(root, text='Female',variable=gender2).grid(row=4,column=2,pady=5)

Address_label=tk.Label(root,text='Address',width=10).grid(row=5,column=0)
Address_entry=tk.Entry(root,textvariable=Address).grid(row=5,column=1,ipadx=20,ipady=20)

city_label=tk.Label(root,text='City',width=10).grid(row=6,column=0)
city_label=tk.Entry(root,textvariable=city).grid(row=6,column=1,pady=5)

pin_label=tk.Label(root,text='Pin',width=10).grid(row=7,column=0)
pin_entry=tk.Entry(root,textvariable=pin,width=8).grid(row=7,column=1,pady=5)

state_label=tk.Label(root,text='State',width=10).grid(row=8,column=0)
state_entry=tk.Entry(root,textvariable=state).grid(row=8,column=1,pady=5)

country_label=tk.Label(root,text='Country',width=10).grid(row=9,column=0)
country_entry=tk.Entry(root,textvariable=Country).grid(row=9,column=1,pady=5)

hobby_lable=tk.Label(root,text="Hobby",width=10).grid(row=10,column=0) 
radiobutton_3 = tk.Checkbutton(root, text='Watching TV', variable=hob1).grid(row=10,column=1,pady=5) 
radiobutton_4 = tk.Checkbutton(root, text='Singing', variable=hob2).grid(row=10,column=2,pady=5)
radiobutton_5 = tk.Checkbutton(root, text='Dancing', variable=hob3).grid(row=11,column=1,pady=5)
radiobutton_6 = tk.Checkbutton(root, text='Singing', variable=hob4).grid(row=11,column=2,pady=5)
hobby=tk.Label(root,text='Others',width=10).grid(row=12,column=1)
hobby5=tk.Entry(root,textvariable=hob5).grid(row=12,column=2,pady=5)

qua_label=tk.Label(root,text='Qualification').grid(row=13,column=0,pady=5)
board_label=tk.Label(root,text='Board').grid(row=14,column=0,pady=5)
Per_label=tk.Label(root,text='Percentage').grid(row=14,column=1,pady=5)
year_label=tk.Label(root,text='Year of passout').grid(row=14,column=2,pady=5)

ten_entry=tk.Label(root,text='Class X').grid(row=15,column=0)
tenben=tk.Entry(root,textvariable=tenb).grid(row=16,column=0,pady=5)
tenpen=tk.Entry(root,textvariable=tenp).grid(row=16,column=1,pady=5)
tenyen=tk.Entry(root,textvariable=teny).grid(row=16,column=2,pady=5)

inter_entry=tk.Label(root,text='Class XII').grid(row=17,column=0)
interben=tk.Entry(root,textvariable=interb).grid(row=18,column=0,pady=5)
interpen=tk.Entry(root,textvariable=interp).grid(row=18,column=1,pady=5)
interyen=tk.Entry(root,textvariable=intery).grid(row=18,column=2,pady=5)

course_label=tk.Label(root,text='Couse Applied For').grid(row=19,column=0)
radiobutton_7 = tk.Radiobutton(root, text='BCA',variable=course1).grid(row=19,column=1,pady=5) 
radiobutton_8 = tk.Radiobutton(root, text='B.Com',variable=course2).grid(row=19,column=2,pady=5)
radiobutton_9 = tk.Radiobutton(root, text='B.SC',variable=course3).grid(row=20,column=1,pady=5)
radiobutton_10 = tk.Radiobutton(root, text='B.A.',variable=course4).grid(row=20,column=2,pady=5)

but_update=tk.Button(root,text='Update',command=root.destroy,w).grid(row=21,column=1) 
but_reset=tk.Button(root,text='Reset',command=root.destroy).grid(row=21,column=2) 


root.mainloop()
# Out:
#   File "C:\Users\karan\AppData\Local\Temp/ipykernel_17932/1347253710.py", line 97
#     but_update=tk.Button(root,text='Update',command=root.destroy,w).grid(row=21,column=1)
#                                                                   ^
# SyntaxError: positional argument follows keyword argument
